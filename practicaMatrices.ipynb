# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovannaCabRuiz/Unidad-2/blob/main/practicaMatrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Producto:
    def __init__(self, clave, nombre, costo, existencia):
        self.clave = clave
        self.nombre = nombre
        self.costo = costo
        self.existencia = existencia
        self.descuento = 0.10
        self.ganancia_total = 0
        self.productos_vendidos = 0

    def aplicar_descuento(self):
        return self.costo - (self.costo * self.descuento)

    def vender(self, cantidad):
        if self.existencia >= cantidad:
            precio_venta = self.aplicar_descuento() * cantidad
            self.ganancia_total += precio_venta
            self.existencia -= cantidad
            self.productos_vendidos += cantidad
            print("Has vendido", cantidad, self.nombre + "(s).")
        else:
            print("No hay suficiente producto en existencia.")

    def mostrar_info(self):
        print("Clave:", self.clave,
              "| Nombre:", self.nombre,
              "| Costo (con 10% desc.):", round(self.aplicar_descuento(), 2),
              "| Existencia:", self.existencia,
              "| Ganancias:", round(self.ganancia_total, 2),
              "| Productos vendidos:", self.productos_vendidos)


def mostrar_menu():
    print("\n--- Menú ---")
    print("1. Agregar producto")
    print("2. Mostrar productos")
    print("3. Vender producto")
    print("4. Mostrar producto más caro y más barato")
    print("5. Salir")


def buscar_producto(clave, matriz_productos):
    for fila in matriz_productos:
        if fila[0].clave == clave:
            return fila[0]
    return


def mostrar_mas_caro_y_barato(matriz_productos):
    if matriz_productos:
        producto_mas_caro = matriz_productos[0][0]
        producto_mas_barato = matriz_productos[0][0]

        for fila in matriz_productos:
            producto = fila[0]
            if producto.costo > producto_mas_caro.costo:
                producto_mas_caro = producto
            if producto.costo < producto_mas_barato.costo:
                producto_mas_barato = producto

        print("\n--- Producto más caro ---")
        print("Nombre:", producto_mas_caro.nombre, "| Costo:", producto_mas_caro.costo)

        print("\n--- Producto más barato ---")
        print("Nombre:", producto_mas_barato.nombre, "| Costo:", producto_mas_barato.costo)
    else:
        print("No hay productos para mostrar.")


matriz_productos = []

while True:
    mostrar_menu()
    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        clave = input("Introduce la clave del producto: ")
        nombre = input("Introduce el nombre del producto: ")
        costo = float(input("Introduce el costo del producto: "))
        existencia = int(input("Introduce la cantidad en existencia: "))


        fila_producto = [Producto(clave, nombre, costo, existencia)]
        matriz_productos.append(fila_producto)
        print("Producto", nombre, "agregado exitosamente.")

    elif opcion == "2":
        print("\n--- Lista de productos ---")
        for fila in matriz_productos:
            fila[0].mostrar_info()  # Accedemos al objeto Producto dentro de cada fila

    elif opcion == "3":
        clave = input("Introduce la clave del producto a vender: ")
        producto = buscar_producto(clave, matriz_productos)
        if producto:
            cantidad = int(input("¿Cuántas unidades de " + producto.nombre + " deseas vender?: "))
            producto.vender(cantidad)
        else:
            print("Producto no encontrado.")

    elif opcion == "4":
        mostrar_mas_caro_y_barato(matriz_productos)

    elif opcion == "5":
        print("Saliendo del programa.")
        break

    else:
        print("Opción no válida. Intenta nuevamente.")
# Out:
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 1
# Introduce la clave del producto: 111
# Introduce el nombre del producto: arroz
# Introduce el costo del producto: 5.00
# Introduce la cantidad en existencia: 10
# Producto arroz agregado exitosamente.
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 1
# Introduce la clave del producto: 222
# Introduce el nombre del producto: pan
# Introduce el costo del producto: 7.00
# Introduce la cantidad en existencia: 15
# Producto pan agregado exitosamente.
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 1
# Introduce la clave del producto: 333
# Introduce el nombre del producto: leche
# Introduce el costo del producto: 20.00
# Introduce la cantidad en existencia: 23
# Producto leche agregado exitosamente.
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 1
# Introduce la clave del producto: 444
# Introduce el nombre del producto: sopa
# Introduce el costo del producto: 32.00
# Introduce la cantidad en existencia: 12
# Producto sopa agregado exitosamente.
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 2
#
# --- Lista de productos ---
# Clave: 111 | Nombre: arroz | Costo (con 10% desc.): 4.5 | Existencia: 10 | Ganancias: 0 | Productos vendidos: 0
# Clave: 222 | Nombre: pan | Costo (con 10% desc.): 6.3 | Existencia: 15 | Ganancias: 0 | Productos vendidos: 0
# Clave: 333 | Nombre: leche | Costo (con 10% desc.): 18.0 | Existencia: 23 | Ganancias: 0 | Productos vendidos: 0
# Clave: 444 | Nombre: sopa | Costo (con 10% desc.): 28.8 | Existencia: 12 | Ganancias: 0 | Productos vendidos: 0
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 3
# Introduce la clave del producto a vender: 231
# Producto no encontrado.
#
# --- Menú ---
# 1. Agregar producto
# 2. Mostrar productos
# 3. Vender producto
# 4. Mostrar producto más caro y más barato
# 5. Salir
# Selecciona una opción: 5
# Saliendo del programa.
